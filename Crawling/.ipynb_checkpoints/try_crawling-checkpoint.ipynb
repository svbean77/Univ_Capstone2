# %% [markdown]
# ## 필요 라이브러리 설치

# %% [markdown]
# !pip install BeautifulSoup4

# %% [markdown]
# !pip install pandas

# %% [markdown]
# !pip install numpy

# %% [markdown]
# ## 기본 html 파싱

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
res = requests.get('https://musclewiki.com/Directory')
soup = BeautifulSoup(res.content, 'html.parser')

lst = soup.find_all('tr')

# %% [markdown]
# ## 필요 데이터 추출

# %%
muscle = []
exercise = []
equipment = []
difficulty = []
link = []

for item in lst:
    txt = [tmp for tmp in item.get_text().split('\n') if tmp]
    if 'Exercises' in item.get_text():
        muscle.append(txt[0].strip()[:-10])
        exercise.append([])
        equipment.append([])
        difficulty.append([])
        link.append([])
        
    else:
        exercise[-1].append(txt[0].strip())
        equipment[-1].append(txt[-2].strip())
        difficulty[-1].append(txt[-1].strip())
        tmp = 'https://musclewiki.com' + item.find('a')['href']
        link[-1].append(tmp)

# %% [markdown]
# ## 데이터프레임 생성

# %%
df_lst = []

for i in range(len(muscle)):
    tmp_df = pd.DataFrame([exercise[i], equipment[i], difficulty[i], link[i]], 
                          index = ['exercise', 'equipment', 'difficulty', 'link']).transpose()
    df_lst.append(tmp_df)

# %% [markdown]
# ## https://www.musclewiki.com + 이미지주소 하면 움짤 주소임!

# %% [markdown]
# df = df_lst[0]
# a = df.loc[0, 'link']
# b = requests.get(a)
# s = BeautifulSoup(b.content, 'html.parser')
# s.find(class_ = 'exercise-images-grid').find('img')['src']

# %% [markdown]
# a = df_lst[4]
# r = requests.get(a.loc[0, 'link'])
# s = BeautifulSoup(r.content, 'html.parser')
# s.get_text()

# %% [markdown]
# for df in df_lst:
#     for i in range(len(df)):
#         tmp_link = df.loc[i, 'link']
#         tmp_res = requests.get(tmp_link)
#         tmp_soup = BeautifulSoup(tmp_res.content, 'html.parser')
#
#
#         if '404' in tmp_soup.get_text():
#             df.loc[i, 'img_link'] = '이미지 주소 오류'
#         else:
#
#             images = tmp_soup.find(class_ = 'exercise-images-grid').find_all('img')
#             print(i, len(images))
#     print()

# %%
a = df_lst[0].loc[0, 'link']
r = requests.get(a)
s = BeautifulSoup(r.content, 'html.parser')

i = s.find(class_ = 'exercise-images-grid')
i.find('a')['href']
b = s.find(class_ = 'steps-list')
t = [i for i in b.get_text().split('\n') if i]
g = ""
for i in range(len(t)):
    g = g + str(i + 1) + '. ' + t[i] + '\n'
    
print(g)
    
tmp = df_lst[0]
tmp.loc[0, 'step'] = g
tmp.loc[0, 'step']
# Out:
# 1. While holding the upper arms stationary, curl the weights forward while contracting the biceps as you breathe out.
# 2. Continue the movement until your biceps are fully contracted and the bar is at shoulder level.
# 3. Hold the contracted position for a second and squeeze the biceps hard.
# 4. Slowly bring the weight back down to the starting position.
# '1. While holding the upper arms stationary, curl the weights forward while contracting the biceps as you breathe out.\n2. Continue the movement until your biceps are fully contracted and the bar is at shoulder level.\n3. Hold the contracted position for a second and squeeze the biceps hard.\n4. Slowly bring the weight back down to the starting position.\n'

# %%
for df in df_lst:
    for i in range(len(df)):
        link = df.loc[i, 'link']
        tmp_res = requests.get(link)
        tmp_soup = BeautifulSoup(tmp_res.content, 'html.parser')
        
        if '404' in tmp_soup.get_text():
            df.loc[i, 'img_link'] = 'no data'
            df.loc[i, 'video_link'] = 'no data'
            df.loc[i, 'step'] = 'no data'
            
        else:
            image = tmp_soup.find(class_ = 'exercise-images-grid')
            if image:
                df.loc[i, 'img_link'] = 'https://www.musclewiki.com' + image.find('img')['src']
                df.loc[i, 'video_link'] = image.find('a')['href']
            else:
                df.loc[i, 'img_link'] = 'no data'
                df.loc[i, 'video_link'] = 'no data'
            
            step_parse = tmp_soup.find(class_ = 'steps-list')
            step_lst = [item for item in step_parse.get_text().split('\n') if item]
            step = ""
            for j in range(len(step_lst)):
                step = step + str(j + 1) + '. ' + step_lst[j] + "\n"
            step = step.strip('\n')
            
            if step:
                df.loc[i, 'step'] = step
            else:
                df.loc[i, 'step'] = 'no data'

# %%
df_lst[11]
# Out:
#                               exercise    equipment    difficulty  \
# 0                             Crunches   Bodyweight      Beginner
# 1                    Laying Leg Raises   Bodyweight      Beginner
# 2                           Leg Raises   Bodyweight  Intermediate
# 3                            Roll Outs      Machine  Intermediate
# 4                                Situp  Kettlebells      Beginner
# 5             Kettlebell Russian Twist  Kettlebells      Beginner
# 6               Kettlebell Woodchopper  Kettlebells      Beginner
# 7                             Windmill  Kettlebells      Beginner
# 8    Abdominals Stretch Variation Four    Stretches      Beginner
# 9   Abdominals Stretch Variation Three    Stretches      Beginner
# 10    Abdominals Stretch Variation Two    Stretches      Beginner
# 11    Abdominals Stretch Variation One    Stretches      Beginner
# 12                       Forearm Plank   Bodyweight      Beginner
# 13                 Hanging Knee Raises   Bodyweight      Beginner
# 14                   Barbell Roll Outs      Barbell  Intermediate
# 15          Barbell Landmine Side Bend      Barbell  Intermediate
# 16                  Cable Wood Chopper       Cables  Intermediate
# 17                     Standing Crunch       Cables      Advanced
# 18                     Kneeling Crunch       Cables      Beginner
# 19                  Cable Pallof Press       Cables      Beginner
# 20                        Wood Chopper         Band      Advanced
# 21                              Crunch         Band  Intermediate
# 22                        Pallof Press         Band      Beginner
# 23                Dumbbell Woodchopper    Dumbbells      Advanced
# 24                      Dumbbell Situp    Dumbbells  Intermediate
# 25                       Russian Twist    Dumbbells  Intermediate
# 26                   Plank Pullthrough    Dumbbells  Intermediate
# 27                       Barbell Situp      Barbell  Intermediate
#
#                                                  link  \
# 0   https://musclewiki.com/Bodyweight/Male/Abdomin...
# 1   https://musclewiki.com/Bodyweight/Male/Abdomin...
# 2   https://musclewiki.com/Bodyweight/Female/Abdom...
# 3   https://musclewiki.com/Machine/Male/Abdominals...
# 4   https://musclewiki.com/Kettlebells/Male/Abdomi...
# 5   https://musclewiki.com/Kettlebells/Male/Abdomi...
# 6   https://musclewiki.com/Kettlebells/Male/Abdomi...
# 7   https://musclewiki.com/Kettlebells/Male/Abdomi...
# 8   https://musclewiki.com/Stretches/Male/Abdomina...
# 9   https://musclewiki.com/Stretches/Male/Abdomina...
# 10  https://musclewiki.com/Stretches/Male/Abdomina...
# 8   https://www.youtube.com/watch?v=ClaHcZch28Q%7C
# 9   https://www.youtube.com/watch?v=ABwpeUOFGf0%7C
# 10  https://www.youtube.com/watch?v=i-xRzmPWxaw%7C
# 11  https://www.youtube.com/watch?v=86oJqpkxxNI%7C
# 12                    https://youtu.be/DkN15y1slTA
# 13                    https://youtu.be/FVFhZa94C6c
# 14                    https://youtu.be/5zaNYdVMHZY
# 15                    https://youtu.be/egxJNnAdTcc
# 16                    https://youtu.be/bGfuynqdCW4
# 17                    https://youtu.be/hscS99_SKwY
# 18                    https://youtu.be/tjzf7MggTJo
# 19                    https://youtu.be/UXXUdsDKh7k
# 20                    https://youtu.be/BMcxTkAonxc
# 21                    https://youtu.be/i4rcQm0SDc8
# 22                    https://youtu.be/1Z8Gn9um8UU
# 23                    https://youtu.be/etl87SX_itM
# 24                    https://youtu.be/LIq_YQqiOtY
# 25                    https://youtu.be/w8JxoO3sSyg
# 26                    https://youtu.be/Mkt6X155DeE
# 27                    https://youtu.be/R9T-P6O5FTM
#
#                                                  step
# 0   1. Lay flat on your back with your knees bent ...
# 1   1. Lay on your back with your arms palms down ...
# 2   1. Lay on your back with your arms palms down ...
# 3   1. Hold the Ab Roller with both hands and knee...
# 4   1. Lay flat on your back with straight legs an...
# 5   1. Sit on the floor with your legs bent, knees...
# 6   1. Stand with feet slightly wider than shoulde...
# 7   1. Stand with feet slightly wider than shoulde...
# 8   1. Lay on a ball or a Bosu ball with your feet...
# 9   1. Reach up with your left arm and then lean s...
# 10  1. Stand upright.\n2. Reach with both hands up...
# 11  1. Lay on your stomach on the floor with your ...
# 12  1. Place forearms on the ground with your elbo...
# 13  1. Grab the bar and hang, your body still and ...
# 14  1. Hold the Barbell with both hands and kneel ...
# 15  1. Stand straight and hold the end of the Barb...
# 16  1. Set the cable at about nipple level. Use a ...
# 17  1. Use a double handle attachment and set the ...
# 18  1. Use a double handle attachment and set the ...
# 19  1. Use a handle attachment, set the cable at n...
# 20                                              error
# 21  1. Place the band at the highest anchor point ...
# 22  1. Place the band at an anchor point that is s...
# 23  1. Stand with a shoulder width stance. Begin w...
# 24  1. Lay flat on the ground with your spine neut...
# 25  1. Sit on the floor and flex your knees and hi...
# 26  1. Get into a plank position. Either from your...
# 27  1. Hold the bar with a slightly wider than sho...

# %%
df = pd.read_csv(path+files[25])
df.loc[13, 'link']
r = requests.get(link)
s = BeautifulSoup(r.content, 'html.parser')
i = s.find(class_ = 'step-list')
if i:
    print('있어')
else:
    print('없어')
# Out:
# 없어

# %% [markdown]
# df = df_lst[14]
# len(df.loc[df['difficulty'] == 'Beginner']) + len(df.loc[df['difficulty'] != 'Beginner'])

# %% [markdown]
# df_lst[0].iloc[0]['link']
# df_lst[0].loc[0, 'img_front'] = 'hello'
# df_lst[0].loc[0, 'img_side'] = 'world'
# df_lst[0]

# %%
df_lst[1].loc[10, 'step']
# Out:
# '1. Raise your arms to shoulder height, fully extended in front of you.\n2. Slowly bring your arms behind your back still at shoulder height.\n3. Pause for a few seconds and then return to starting position.\n'

# %%
beginner = []
master = []

for df in df_lst:
    beginner.append(df.loc[df['difficulty'] == 'Beginner'])
    master.append(df.loc[df['difficulty'] != 'Beginner'])

# %%
for i in range(len(df)):
    b_filename = "eng_Beginner_" + muscle[i]
    m_filename = "eng_Master_"+ muscle[i]
    
    b_df = beginner[i].loc[beginner[i]['difficulty'] == 'Beginner']
    m_df = master[i].loc[master[i]['difficulty'] != 'Beginner']
    
    b_df.to_csv('data/' + b_filename + '.csv', index = False)
    m_df.to_csv('data/' + m_filename + '.csv', index = False)

# %%
beginner[0]
# Out:
#                           exercise    equipment difficulty  \
# 0                     Barbell Curl      Barbell   Beginner
# 1                    Dumbbell Curl    Dumbbells   Beginner
# 2             Dumbbell Hammer Curl    Dumbbells   Beginner
# 3                      Goblet Curl  Kettlebells   Beginner
# 6                  Single Arm Curl  Kettlebells   Beginner
# 7    Biceps Stretch Variation Five    Stretches   Beginner
# 8    Biceps Stretch Variation Four    Stretches   Beginner
# 9   Biceps Stretch Variation Three    Stretches   Beginner
# 10    Biceps Stretch Variation Two    Stretches   Beginner
# 11    Biceps Stretch Variation One    Stretches   Beginner
# 12                    Inverted Row   Bodyweight   Beginner
# 15                   Bayesian Curl       Cables   Beginner
# 17               Cable Hammer Curl       Cables   Beginner
# 18                            Curl         Band   Beginner
# 20    Kneeling Single Arm Pulldown         Band   Beginner
# 23         Dumbbell Row Unilateral    Dumbbells   Beginner
#
#                                                  link  \
# 0   https://musclewiki.com/Barbell/Male/Biceps/Bar...
# 1   https://musclewiki.com/Dumbbells/Male/Biceps/D...
# 2   https://musclewiki.com/Dumbbells/Male/Biceps/D...
# 3   https://musclewiki.com/Kettlebells/Male/Biceps...
# 6   https://musclewiki.com/Kettlebells/Male/Biceps...
# 7   https://musclewiki.com/Stretches/Male/Biceps/B...
# 8   https://musclewiki.com/Stretches/Male/Biceps/B...
# 9   https://musclewiki.com/Stretches/Male/Biceps/B...
# 10  https://musclewiki.com/Stretches/Male/Biceps/B...
# 11  https://musclewiki.com/Stretches/Male/Biceps/B...
# 12  https://musclewiki.com/Bodyweight/Male/Biceps/...
# 15  https://musclewiki.com/Cables/Male/Biceps/Baye...
# 17  https://musclewiki.com/Cables/Male/Biceps/Cabl...
# 18       https://musclewiki.com/Band/Male/Biceps/Curl
# 20  https://musclewiki.com/Band/Male/Biceps/Kneeli...
# 23  https://musclewiki.com/Dumbbells/Male/Biceps/D...
#
#                                                  step  \
# 0   1. While holding the upper arms stationary, cu...
# 1   1. Stand up straight with a dumbbell in each h...
# 2   1. Hold the dumbbells with a neutral grip (thu...
# 3   1. Stand up straight with a kettlebell in both...
# 6   1. Stand up straight with a kettlebell in one ...
# 7   1. Stand upright with your feet shoulder width...
# 8   1. Stand an arms width away from the wall.\n2....
# 9   1. Bend your arm at the elbow, raising your ha...
# 10  1. Stand facing the wall, an arm's width away....
# 11  1. Stand one foot in front of the other with t...
# 12  1. Lay underneath a fixed horizontal bar and g...
# 15  1. Use a handle attachment. The cable should b...
# 17  1. Use a handle attachment. The cable should b...
# 18  1. Attach band to a low anchor point. Point yo...
# 20  1. Place the band at about eye level. Fall int...
# 23  1. Brace your off arm against something stable...
#
#                                              img_link  \
# 0   https://www.musclewiki.com/media/uploads/male-...
# 1   https://www.musclewiki.com/media/uploads/male-...
# 2   https://www.musclewiki.com/media/uploads/male-...
# 3   https://www.musclewiki.com/media/uploads/male-...
# 6   https://www.musclewiki.com/media/uploads/male-...
# 7   https://www.musclewiki.com/media/uploads/male-...
# 8   https://www.musclewiki.com/media/uploads/male-...
# 9   https://www.musclewiki.com/media/uploads/male-...
# 10  https://www.musclewiki.com/media/uploads/male-...
# 11  https://www.musclewiki.com/media/uploads/male-...
# 12  https://www.musclewiki.com/media/uploads/bodyw...
# 15  https://www.musclewiki.com/media/uploads/male-...
# 17  https://www.musclewiki.com/media/uploads/male-...
# 18  https://www.musclewiki.com/media/uploads/male-...
# 20  https://www.musclewiki.com/media/uploads/male-...
# 23  https://www.musclewiki.com/media/uploads/male-...
#
#                                         video_link
# 0                     https://youtu.be/0mylYdVWBf0
# 1                     https://youtu.be/EU4HlSIpj5Y
# 2                     https://youtu.be/Dh3_gou_3TE
# 3                     https://youtu.be/oYmItLMNFg0
# 6                     https://youtu.be/jiheWHzzIJ4
# 7   https://www.youtube.com/watch?v=7jXK9pNJdJg%7C
# 8   https://www.youtube.com/watch?v=IRxy-WjmBRs%7C
# 9   https://www.youtube.com/watch?v=koCz9-ZVjRg%7C
# 10  https://www.youtube.com/watch?v=_qFHL-DoHG8%7C
# 11                    https://youtu.be/KPMttUk2xM8
# 12                    https://youtu.be/EuT4-4OFySE
# 15                    https://youtu.be/VlACMxVsaF8
# 17                    https://youtu.be/tOxNeSx_P70
# 18                    https://youtu.be/7f1kaMkOdk4
# 20                    https://youtu.be/2bA1aTxHm5U
# 23                    https://youtu.be/P8lNvP8SsQk

# %% [markdown]
# ## 한글로 번역

# %%
import os

path = './data/'
files = os.listdir(path)

# %%
a = pd.read_csv(path + files[25])
files[0].replace('eng', 'kor')
# Out:
# 'kor_Beginner_Abdominals.csv'

# %%
txt = '데이터 없음'
translator.translate(txt, dest = 'en', src = 'auto').text
# Out:
# 'no data'

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
# Requirement already satisfied: certifi in c:\users\svbea\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2021.10.8)
# Collecting hstspreload
#   Downloading hstspreload-2022.10.1-py3-none-any.whl (1.4 MB)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting idna==2.*
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
# Collecting chardet==3.*
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Requirement already satisfied: sniffio in c:\users\svbea\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.2.0)
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py): started
#   Building wheel for googletrans (setup.py): finished with status 'done'
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17429 sha256=7d5a51f1c2399a5dcbadbc90c99e14a70d1594e079c98ef2c0ad34e1e9ce6b14
#   Stored in directory: c:\users\svbea\appdata\local\pip\cache\wheels\60\b3\27\d8aff3e2d5c2d0d97a117cdf0d5f13cd121e2c2b5fb49b55a0
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, h2, h11, rfc3986, idna, httpcore, hstspreload, chardet, httpx, googletrans
#   Attempting uninstall: idna
#     Found existing installation: idna 3.3
#     Uninstalling idna-3.3:
#       Successfully uninstalled idna-3.3
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2022.10.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
import googletrans

# %%
translator = googletrans.Translator()

for i in range(len(a)):
    step = a.loc[i, 'step']
    #equipment = a.loc[i, 'equipment']
    #exercise = a.loc[i, 'exercise']
    print(step)
    if step != 'error':
        trans = translator.translate(step, dest = 'ko', src = 'en')
        a.loc[i, 'step'] = trans.text
        print(trans.text)
        
    a.to_csv(path+files[0].replace('eng', 'kor'), encoding = 'utf-8-sig')
    #print(trans.text)
    print()
# Out:
# error
#
# 1. Sit on the bench and hold a dumbbell with both hands. Raise the dumbbell overhead at arms length, holding the weight up with the palms of your hands.
# 2. Keep your elbows in while you lower the weight behind your head, your upper arms stationary.
# 3. Raise the weight back to starting position.
# 1. 벤치에 앉아 양손으로 아령을 잡고 있습니다.팔 길이로 아령 오버 헤드를 올려 손바닥으로 무게를 올리십시오.
# 2. 머리 뒤에 무게를 낮추는 동안 팔꿈치를 유지하십시오.
# 3. 체중을 다시 시작 위치로 올립니다.
#
# 1. Lay on a flat bench while holding a barbell with a shoulder-width grip.
# 2. Fully extend your elbows until the barbell is directly over your chest.
# 3. Begin to flex your elbows and allow the barbell to nearly touch your forehead.
# 4. Extend your elbows back to the starting position and repeat.
# 1. 어깨 너비 그립이있는 바벨을 들고 평평한 벤치에 놓으십시오.
# 2. 바벨이 가슴 바로 위에 올 때까지 팔꿈치를 완전히 확장하십시오.
# 3. 팔꿈치를 구부리기 시작하고 바벨이 이마를 거의 만지도록하십시오.
# 4. 팔꿈치를 시작 위치로 다시 뻗어 반복하십시오.
#
# 1. Lie on your back with knees in the air and soles of your feet flat on the floor.
# 2. Hold the kettlebell in both hands directly above your chest.
# 3. Keeping your upper arms in place, bend your elbows to slowly bring the kettlebell in front of your forehead.
# 4. Return to the starting position and repeat.
# 1. 공중에서 무릎을 꿇고 발바닥이 바닥에 평평하게 등을 대고 눕습니다.
# 2. 케틀벨을 가슴 바로 위로 양손으로 잡습니다.
# 3. 팔을 제자리에두고 팔꿈치를 구부려 천천히 케틀벨을 이마 앞쪽으로 가져옵니다.
# 4. 시작 위치로 돌아가서 반복하십시오.
#
# 1. Lie on the floor with your upper back and soles of feet on the floor, knees bent, and pelvis and lower back suspended in the air.
# 2. Hold the kettlebell in both hands directly above your chest.
# 3. Keeping your upper arms in place, bend your elbows to bring the kettlebell to the floor above your head.
# 4. Return the kettlebell to the starting position and repeat.
# 1. 윗부분과 발바닥이 바닥에 눕고, 무릎이 구부러지고 골반이 공기에 매달려 있습니다.
# 2. 케틀벨을 가슴 바로 위로 양손으로 잡습니다.
# 3. 팔을 제자리에두고 팔꿈치를 구부려 케틀벨을 머리 위의 바닥으로 가져옵니다.
# 4. 케틀벨을 시작 위치로 되돌리고 반복합니다.
#
# 1. Lie flat on your back. Keeping your arm straight, hold the kettlebell above your chest with your palm facing away from your body.
# 2. Bend your arm, touching the kettlebell to the top of the shoulder opposite to the arm being worked.
# 3. Return to the starting position and repeat.
# 1. 등에 평평하게 눕습니다.팔을 똑바로 유지하고 손바닥을 몸에서 멀어지게하여 가슴 위의 케틀벨을 잡고 있습니다.
# 2. 팔을 구부리면서 케틀벨을 어깨의 꼭대기에 닿아 팔이 작동하는 팔과 반대됩니다.
# 3. 시작 위치로 돌아가서 반복하십시오.
#
# 1. Use a bench or an object to elevate your feet.
# 2. Lower your head towards the floor by bending your elbows
# 3. Push through your hands and return to the starting pike position.
# 4. Repeat
# 1. 벤치 나 물체를 사용하여 발을 높이십시오.
# 2. 팔꿈치를 구부려 머리를 바닥쪽으로 내립니다.
# 3. 손을 뚫고 시작 파이크 위치로 돌아갑니다.
# 4. 반복하십시오
#
# 1. Hold your body with arms locked above the equipment
# 2. Lower your body slowly while leaning forward, flare out your elbows
# 3. Raise your body above the bars until your arms are locked.
# 1. 장비 위에 팔을 잠긴 상태에서 몸을 잡고
# 2. 앞으로 기대면서 천천히 몸을 내리고 팔꿈치를 벗겨냅니다.
# 3. 팔이 잠겨질 때까지 몸을 바로 올려 놓으십시오.
#
# 1. Lay flat on the bench with your feet on the ground. With a narrow grip on the bar, straighten your arms
# 2. Lower the bar to your lower-mid chest
# 3. Slowly raise the bar until you've locked your elbows.
# 1. 땅에 발을두고 벤치에 평평하게 놓으십시오.막대에 좁은 그립으로 팔을 똑바로 펴십시오.
# 2. 막대를 낮은 미드 가슴으로 낮 춥니 다
# 3. 팔꿈치를 잠글 때까지 천천히 막대를 올리십시오.
#
# 1. Either use two handles or no attachment at all. Both sides of the cable crossover should be set to the top.
# 2. Stand in the center of the machine holding each Cable in the opposing hand. Your upper arm should be at a 45 degree angle with your torso.
# 3. Extend your elbows until you feel a contraction and then return to the starting position
# 1. 두 핸들을 사용하거나 첨부 파일이 전혀 사용되지 않습니다.케이블 크로스 오버의 양쪽을 상단으로 설정해야합니다.
# 2. 각 케이블을 반대 손에 잡는 기계의 중앙에 서십시오.상단 팔은 몸통과 함께 45도 각도에 있어야합니다.
# 3. 수축이 느껴질 때까지 팔꿈치를 연장 한 다음 시작 위치로 돌아갑니다.
#
# 1. You can use a straight bar, rope, easy bar, or two handles. The cable should be set all the way to the top of the machine.
# 2. Face away from the machine with your elbows up and the attachment just behind your head.
# 3. Extend at the elbows until you feel a contraction in your triceps and then flex at the elbow back to the starting position.
# 1. 직선 막대, 로프, 쉬운 막대 또는 두 개의 핸들을 사용할 수 있습니다.케이블은 기계 상단까지 완전히 설정해야합니다.
# 2. 팔꿈치를 올라가고 머리 바로 뒤에 부착물을 사용하여 기계에서 멀어집니다.
# 3. 삼두근에 수축을 느낄 때까지 팔꿈치를 뻗은 다음 팔꿈치를 시작 위치로 다시 구부립니다.
#
# 1. You can use any attachment. The cable should be all the way to the bottom of the machine. Face away from the machine.
# 2. Point your elbows straight up toward the ceiling.
# 3. From there, extend your elbows until your fists are pointed straight toward the ceiling.
# 1. 첨부 파일을 사용할 수 있습니다.케이블은 기계의 바닥까지이어야합니다.기계에서 멀리 얼굴을 맞추십시오.
# 2. 팔꿈치를 천장쪽으로 똑바로 향하게하십시오.
# 3. 거기에서 주먹이 천장을 향해 똑바로 향할 때까지 팔꿈치를 뻗어 있습니다.
#
# 1. Stand with one or both feet on band. Go up and over your head with the band to the starting position.
# 2. Flex and extend your elbows.
# 1. 밴드에 하나 또는 양쪽 발로 서십시오.밴드와 함께 머리 위로 올라가서 시작 위치로 올라갑니다.
# 2. 팔꿈치를 구부리고 확장하십시오.
#
# error
#
# 1. Lay flat on the floor or a bench with your fists extended to the ceiling and a neutral grip.
# 2. Break at the elbows until your fists are by your temples. Then extend your elbows and flex your triceps at the top.
# 1. 주먹을 천장과 중립 그립으로 뻗은 바닥 또는 벤치에 평평하게 놓으십시오.
# 2. 주먹이 사원 옆에있을 때까지 팔꿈치를 부수십시오.그런 다음 팔꿈치를 뻗고 삼두근을 상단에서 구부립니다.
#
# 1. Un-rack the bar and break at the elbows and shoulders.
# 2. Bring your elbows to the floor, rest for a second to remove all the momentum from the rep, then press to a lockout.
# 1. 막대를 풀고 팔꿈치와 어깨를 부수십시오.
# 2. 팔꿈치를 바닥으로 가져 가서 1 초 동안 휴식을 취하여 담당자에서 모든 운동량을 제거한 다음 잠금으로 누릅니다.
#
# 1. Take a shoulder width grip. Break at the elbows. Try to keep your elbows tucked in. Don't let them flare out.
# 2. Stop the bar a few inches from your forehead and extend your elbows back up.
# 1. 어깨 너비 그립을 잡습니다.팔꿈치를 부수십시오.팔꿈치를 집어 넣으십시오. 플레어를 꺼내지 마십시오.
# 2. 이마에서 몇 인치 떨어진 막대를 멈추고 팔꿈치를 백업하십시오.
#
# 1. Be careful getting the bar into place overhead. Push your elbows forward while keeping your elbows tucked in.
# 2. Look for what feels like a stretch in your triceps. Extend your elbows until your fists are pointed at the ceiling.
# 1. 막대를 오버 헤드로 제자리에 놓으십시오.팔꿈치를 넣는 동안 팔꿈치를 앞으로 밀어 넣으십시오.
# 2. 삼두근에 늘어나는 느낌을 찾으십시오.주먹이 천장을 가리킬 때까지 팔꿈치를 연장하십시오.

# %%
a
# Out:
#                              exercise    equipment    difficulty  \
# 0                Dips (narrow elbows)   Bodyweight      Advanced
# 1           Seated Triceps Extensions    Dumbbells  Intermediate
# 2           Laying Triceps Extensions      Barbell  Intermediate
# 3            Kettlebell Skull Crusher  Kettlebells      Advanced
# 4               Decline Skull Crusher  Kettlebells      Advanced
# 5                          Tate Press  Kettlebells  Intermediate
# 6                 Elevated Pike Press   Bodyweight  Intermediate
# 7                                Dips   Bodyweight  Intermediate
# 8              Close Grip Bench Press      Barbell  Intermediate
# 9                      Cross Pushdown       Cables      Advanced
# 10                 Cable Skullcrusher       Cables  Intermediate
# 11    Cable Overhead Tricep Extension       Cables  Intermediate
# 12          Overhead Tricep Extension         Band      Advanced
# 13                  Band Skullcrusher         Band      Advanced
# 14              Dumbbell Skullcrusher    Dumbbells  Intermediate
# 15                        Floor Press      Barbell      Advanced
# 16               Barbell Skullcrusher      Barbell  Intermediate
# 17  Barbell Overhead Tricep Extension      Barbell      Advanced
#
#                                                  link  \
# 0   https://musclewiki.com/Bodyweight/Male/Triceps...
# 1   https://musclewiki.com/Dumbbells/Male/Triceps/...
# 2   https://musclewiki.com/Barbell/Male/Triceps/La...
# 3   https://musclewiki.com/Kettlebells/Male/Tricep...
# 4   https://musclewiki.com/Kettlebells/Male/Tricep...
# 5   https://musclewiki.com/Kettlebells/Male/Tricep...
# 6   https://musclewiki.com/Bodyweight/Male/Traps/E...
# 6   1. 벤치 나 물체를 사용하여 발을 높이십시오.\n2. 팔꿈치를 구부려 머리를 바닥...
# 7   1. 장비 위에 팔을 잠긴 상태에서 몸을 잡고\n2. 앞으로 기대면서 천천히 몸을 ...
# 8   1. 땅에 발을두고 벤치에 평평하게 놓으십시오.막대에 좁은 그립으로 팔을 똑바로 펴...
# 9   1. 두 핸들을 사용하거나 첨부 파일이 전혀 사용되지 않습니다.케이블 크로스 오버의...
# 10  1. 직선 막대, 로프, 쉬운 막대 또는 두 개의 핸들을 사용할 수 있습니다.케이블...
# 11  1. 첨부 파일을 사용할 수 있습니다.케이블은 기계의 바닥까지이어야합니다.기계에서 ...
# 12  1. 밴드에 하나 또는 양쪽 발로 서십시오.밴드와 함께 머리 위로 올라가서 시작 위...
# 13                                              error
# 14  1. 주먹을 천장과 중립 그립으로 뻗은 바닥 또는 벤치에 평평하게 놓으십시오.\n2...
# 15  1. 막대를 풀고 팔꿈치와 어깨를 부수십시오.\n2. 팔꿈치를 바닥으로 가져 가서 ...
# 16  1. 어깨 너비 그립을 잡습니다.팔꿈치를 부수십시오.팔꿈치를 집어 넣으십시오. 플레...
# 17  1. 막대를 오버 헤드로 제자리에 놓으십시오.팔꿈치를 넣는 동안 팔꿈치를 앞으로 밀...

# %%
pd.read_csv(path+files[25])
# Out:
#                              exercise    equipment    difficulty  \
# 0                Dips (narrow elbows)   Bodyweight      Advanced
# 1           Seated Triceps Extensions    Dumbbells  Intermediate
# 2           Laying Triceps Extensions      Barbell  Intermediate
# 3            Kettlebell Skull Crusher  Kettlebells      Advanced
# 4               Decline Skull Crusher  Kettlebells      Advanced
# 5                          Tate Press  Kettlebells  Intermediate
# 6                 Elevated Pike Press   Bodyweight  Intermediate
# 7                                Dips   Bodyweight  Intermediate
# 8              Close Grip Bench Press      Barbell  Intermediate
# 9                      Cross Pushdown       Cables      Advanced
# 10                 Cable Skullcrusher       Cables  Intermediate
# 11    Cable Overhead Tricep Extension       Cables  Intermediate
# 12          Overhead Tricep Extension         Band      Advanced
# 13                  Band Skullcrusher         Band      Advanced
# 14              Dumbbell Skullcrusher    Dumbbells  Intermediate
# 15                        Floor Press      Barbell      Advanced
# 16               Barbell Skullcrusher      Barbell  Intermediate
# 17  Barbell Overhead Tricep Extension      Barbell      Advanced
#
#                                                  link  \
# 0   https://musclewiki.com/Bodyweight/Male/Triceps...
# 1   https://musclewiki.com/Dumbbells/Male/Triceps/...
# 2   https://musclewiki.com/Barbell/Male/Triceps/La...
# 3   https://musclewiki.com/Kettlebells/Male/Tricep...
# 4   https://musclewiki.com/Kettlebells/Male/Tricep...
# 5   https://musclewiki.com/Kettlebells/Male/Tricep...
# 6   https://musclewiki.com/Bodyweight/Male/Traps/E...
# 7   https://musclewiki.com/Bodyweight/Male/Chest/Dips
# 8   https://musclewiki.com/Barbell/Male/Triceps/Cl...
# 9   https://musclewiki.com/Cables/Male/Triceps/Cro...
# 10  https://musclewiki.com/Cables/Male/Triceps/Cab...
