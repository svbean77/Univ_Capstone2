# %%
import os
import pandas as pd

path = './data/'
files = os.listdir(path)
file = files[26]

df = pd.read_csv(path + file)

# %%
for i in range(len(df)):
    print(df.loc[i, 'image1'])
    print(df.loc[i, 'image2'])
    print()
# Out:
# https://www.musclewiki.com/media/uploads/male-barbell-curl-front_uKPCb8P.gif
# https://www.musclewiki.com/media/uploads/male-barbell-curl-side_NN1ZFmi.gif
#
# https://www.musclewiki.com/media/uploads/male-dumbbell-curl-front.gif
# https://www.musclewiki.com/media/uploads/male-dumbbell-curl-side.gif
#
# https://www.musclewiki.com/media/uploads/male-dumbbell-hammer-curl-front_JbvhNLU.gif
# https://www.musclewiki.com/media/uploads/male-dumbbell-hammer-curl-side_io6oHN7.gif
#
# https://www.musclewiki.com/media/uploads/male-kettlebell-goblet-curl-front_BYaNghv.gif
# https://www.musclewiki.com/media/uploads/male-kettlebell-goblet-curl-side_ppCoczg.gif
#
# https://www.musclewiki.com/media/uploads/male-kettlebell-concentration-curl-front.gif
# https://www.musclewiki.com/media/uploads/male-kettlebell-concentration-curl-side.gif
#
# https://www.musclewiki.com/media/uploads/male-kettlebell-preacher-curl-front.gif
# https://www.musclewiki.com/media/uploads/male-kettlebell-preacher-curl-side.gif
# ...
